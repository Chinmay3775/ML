# %%
import pandas as pd

# %%
df= pd.read_csv('htwt.csv')
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
df.shape
# Out:
# (25000, 3)

# %%
df.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %%
x=df.iloc[:50,[1,2]].values
x
# Out:
# array([[ 65.78331, 112.9925 ],
#        [ 71.51521, 136.4873 ],
#        [ 69.39874, 153.0269 ],
#        [ 68.2166 , 142.3354 ],
#        [ 67.78781, 144.2971 ],
#        [ 68.69784, 123.3024 ],
#        [ 69.80204, 141.4947 ],
#        [ 70.01472, 136.4623 ],
#        [ 67.90265, 112.3723 ],
#        [ 66.78236, 120.6672 ],
#        [ 66.48769, 127.4516 ],
#        [ 67.62333, 114.143  ],
#        [ 68.30248, 125.6107 ],
#        [ 67.11656, 122.4618 ],
#        [ 68.27967, 116.0866 ],
#        [ 71.0916 , 139.9975 ],
#        [ 66.461  , 129.5023 ],
#        [ 68.64927, 142.9733 ],
#        [ 71.23033, 137.9025 ],
#        [ 67.13118, 124.0449 ],
#        [ 67.83379, 141.2807 ],
#        [ 68.87881, 143.5392 ],
#        [ 63.48115,  97.90191],
#        [ 68.42187, 129.5027 ],
#        [ 67.62804, 141.8501 ],
#        [ 67.20864, 129.7244 ],
#        [ 70.84235, 142.4235 ],
#        [ 67.49434, 131.5502 ],
#        [ 66.53401, 108.3324 ],
#        [ 65.44098, 113.8922 ],
# ...

# %%
x.ndim
# Out:
# 2

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans(n_clusters=3)
model.fit(x)
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
y_pred =model.predict(x)
y_pred
# Out:
# array([2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 1, 2, 1, 1, 2, 0, 1, 0, 0, 1, 0, 0,
#        2, 1, 0, 1, 0, 1, 2, 2, 2, 1, 1, 0, 0, 1, 0, 1, 1, 2, 1, 1, 0, 0,
#        2, 1, 0, 2, 0, 0])

# %%
x[y_pred==0,0]
# Out:
# array([71.51521, 69.39874, 68.2166 , 67.78781, 69.80204, 70.01472,
#        71.0916 , 68.64927, 71.23033, 67.83379, 68.87881, 67.62804,
#        70.84235, 70.59505, 71.80484, 66.80368, 69.65814, 67.96731,
#        66.88088, 69.82117, 69.08817])

# %%
x[y_pred==0,1]
# Out:
# array([136.4873, 153.0269, 142.3354, 144.2971, 141.4947, 136.4623,
#        139.9975, 142.9733, 137.9025, 141.2807, 143.5392, 141.8501,
#        142.4235, 136.2225, 140.1015, 141.7994, 139.6711, 137.3696,
#        145.6837, 143.6215, 134.9325])

# %%
x[y_pred==1,0]
# Out:
# array([68.69784, 66.78236, 66.48769, 68.30248, 67.11656, 66.461  ,
#        67.13118, 68.42187, 67.20864, 67.49434, 65.8132 , 67.8163 ,
#        69.20613, 67.65893, 67.80701, 68.57463, 65.18357, 68.67249])

# %%
x[y_pred==1,1]
# Out:
# array([123.3024, 120.6672, 127.4516, 125.6107, 122.4618, 129.5023,
#        124.0449, 129.5027, 129.7244, 131.5502, 120.7536, 125.7886,
#        128.7487, 121.2319, 131.3478, 124.3598, 124.8591, 128.7639])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x[y_pred==0,0],x[y_pred==0,1],s=10,c='red' ,label='cluster 1')
plt.scatter(x[y_pred==1,0],x[y_pred==1,1],s=10,c='g',label='cluster 2')
plt.scatter(x[y_pred==2,0],x[y_pred==2,1],s=10,c='b',label='cluster 3')
plt.scatter(model.cluster_centers_[:,0],model.cluster_centers_[:,1],c='yellow',s=150)
plt.legend()
plt.show()

# %%
# Out:
# array([[ 66.90263864, 116.79702318],
#        [ 68.95642964, 138.30758214]])
